# %% [markdown]
# # **Image Sampling and Quantization with Python**

# %% [markdown]
# A. Reducing Quantization Values:

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import imageio as io

# %%
# Create a sample image
img = np.random.rand(256, 256)
print(img)

# Reduce the quantization values to 2 bits (4 levels)
reduced_img_2bits = np.round(img * 3) / 3
# Reduce the quantization values to 1 bit (2 levels)
reduced_img_1bit = np.round(img)



# Display the images
plt.subplot(1, 3, 1)
plt.imshow(img, cmap='gray')
plt.title('Original Image')
plt.subplot(1, 3, 2)
plt.imshow(reduced_img_2bits, cmap='gray')
plt.title('2 bits (4 levels)')
plt.subplot(1, 3, 3)
plt.imshow(reduced_img_1bit, cmap='gray')
plt.title('1 bit (2 levels)')
plt.show()
# Out:
# [[0.00263614 0.08155643 0.52963918 ... 0.42525156 0.25579538 0.89367069]
#  [0.72521319 0.23039755 0.24453257 ... 0.63498897 0.01786769 0.42219406]
#  [0.16988738 0.27281718 0.87033645 ... 0.6544848  0.65971915 0.32927272]
#  ...
#  [0.15258752 0.78865653 0.71601773 ... 0.33261065 0.74658668 0.88298688]
#  [0.91558263 0.24997573 0.04669181 ... 0.89359967 0.21918148 0.844204  ]
#  [0.83788123 0.79404297 0.58270091 ... 0.60238186 0.07538614 0.15339287]]

# %% [markdown]
# B. Reducing the Number of Samples:

# %%
# Reduce the number of samples to half
reduced_img_half = img[::2, ::2]
# Reduce the number of samples to quarter
reduced_img_quarter = img[::4, ::4]


# Display the images
plt.subplot(1, 3, 1)
plt.imshow(img, cmap='gray')
plt.title('Original Image')
plt.subplot(1, 3, 2)
plt.imshow(reduced_img_half, cmap='gray')
plt.title('Half Resolution')
plt.subplot(1, 3, 3)
plt.imshow(reduced_img_quarter, cmap='gray')
plt.title('Quarter Resolution')
plt.show()

# %% [markdown]
# C. Reducing Both Quantization Values and Number of Samples:

# %%
# Reduce the quantization values to 2 bits (4 levels) and number of samples to half
reduced_img_2bits_half = np.round(img[::2, ::2] * 3) / 3
# Reduce the quantization values to 1 bit (2 levels) and number of samples to quarter
reduced_img_1bit_quarter = np.round(img[::4, ::4])



# Display the images
plt.subplot(1, 3, 1)
plt.imshow(img, cmap='gray')
plt.title('Original Image')
plt.subplot(1, 3, 2)
plt.imshow(reduced_img_2bits_half, cmap='gray')
plt.title('2 bits (4 levels), Half Resolution')
plt.subplot(1, 3, 3)
plt.imshow(reduced_img_1bit_quarter, cmap='gray')
plt.title('1 bit (2 levels), Quarter Resolution')
plt.show()

# %% [markdown]
# # **Histograms in Image Processing**

# %%
imghist=io.imread("/content/image.webp")
imghist
# Out:
# <ipython-input-7-7fd8a90b6fcf>:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   imghist=io.imread("/content/image.webp")
# array([[[ 79, 129, 160],
#         [ 79, 129, 160],
#         [ 79, 129, 160],
#         ...,
#         [ 76, 113, 139],
#         [ 81, 117, 144],
#         [ 83, 120, 146]],
#
#        [[ 82, 131, 162],
#         [ 82, 131, 162],
#         [ 82, 131, 162],
#         ...,
#         [ 77, 114, 140],
#         [ 80, 116, 143],
#         [ 81, 117, 144]],
#
#        [[ 84, 134, 165],
#         [ 84, 134, 165],
#         [ 84, 134, 165],
#         ...,
#         [ 80, 116, 143],
#         [ 77, 114, 140],
#         [ 76, 113, 139]],
#
#        ...,
#
#        [[ 31,  17,  17],
#         [ 26,  12,  12],
#         [ 26,  12,  12],
#         ...,
#         [ 58,  44,  32],
#         [ 50,  33,  23],
#         [ 42,  25,  15]],
#
#        [[ 31,  17,  15],
#         [ 31,  17,  15],
#         [ 31,  17,  15],
#         ...,
#         [ 57,  41,  28],
#         [ 51,  35,  22],
#         [ 49,  33,  20]],
#
#        [[ 31,  17,  15],
#         [ 31,  17,  15],
#         [ 31,  17,  15],
#         ...,
#         [ 51,  35,  22],
#         [ 49,  33,  18],
#         [ 49,  33,  18]]], dtype=uint8)

# %% [markdown]
# hist = cv2.calcHist([images], [channels], mask, [hist size], range of pixel intensity)

# %%
imghist=cv.cvtColor(imghist,cv.COLOR_BGR2GRAY)
imghist
# Out:
# array([[133, 133, 133, ..., 117, 121, 124],
#        [135, 135, 135, ..., 118, 120, 121],
#        [138, 138, 138, ..., 120, 118, 117],
#        ...,
#        [ 19,  14,  14, ...,  42,  32,  24],
#        [ 18,  18,  18, ...,  39,  33,  31],
#        [ 18,  18,  18, ...,  33,  30,  30]], dtype=uint8)

# %%
#histogram calculation

hist1=cv.calcHist([imghist],[0],None,[256],[0,256])


plt.figure()
plt.xlabel('bins')
plt.ylabel('# No of pixels')
plt.plot(hist1)
plt.xlim([0, 256])
plt.show()

# %%
hist2, bins, _ = plt.hist(imghist.ravel(), bins=256, range=[0, 256])  # Get histogram data

# Display the histogram as a 1D plot instead of using imshow.
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.title('Image Histogram')

plt.show()

# %%
img=cv.cvtColor(imghist,cv.COLOR_GRAY2BGR)
(b, g, r) = cv.split(img)
#calculate histograms separately of B , G and R channel
hist_b = cv.calcHist([b], [0], None, [256], [0, 256])
hist_g = cv.calcHist([g], [0], None, [256], [0, 256])
hist_r = cv.calcHist([r], [0], None, [256], [0, 256])


plt.figure()
plt.title('color_histograms')
plt.xlabel('bins')
plt.ylabel('# of pixels')
plt.plot(hist_b, color='b')
plt.plot(hist_g, color='g')
plt.plot(hist_r, color='r')
plt.show()
# Out:
# array([[[133, 133, 133],
#         [133, 133, 133],
#         [133, 133, 133],
#         ...,
#         [117, 117, 117],
#         [121, 121, 121],
#         [124, 124, 124]],
#
#        [[135, 135, 135],
#         [135, 135, 135],
#         [135, 135, 135],
#         ...,
#         [118, 118, 118],
#         [120, 120, 120],
#         [121, 121, 121]],
#
#        [[138, 138, 138],
#         [138, 138, 138],
#         [138, 138, 138],
#         ...,
#         [120, 120, 120],
#         [118, 118, 118],
#         [117, 117, 117]],
#
#        ...,
#
#        [[ 19,  19,  19],
#         [ 14,  14,  14],
#         [ 14,  14,  14],
#         ...,
#         [ 42,  42,  42],
#         [ 32,  32,  32],
#         [ 24,  24,  24]],
#
#        [[ 18,  18,  18],
#         [ 18,  18,  18],
#         [ 18,  18,  18],
#         ...,
#         [ 39,  39,  39],
#         [ 33,  33,  33],
#         [ 31,  31,  31]],
#
#        [[ 18,  18,  18],
#         [ 18,  18,  18],
#         [ 18,  18,  18],
#         ...,
#         [ 33,  33,  33],
#         [ 30,  30,  30],
#         [ 30,  30,  30]]], dtype=uint8)
